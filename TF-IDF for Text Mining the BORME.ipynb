# %% [markdown]
# # Initialization
#
# First, let's initialize the notebook

# %%
import os
import re
import math
import nltk

from nltk.tokenize import RegexpTokenizer
from nltk import bigrams
from nltk import trigrams

nltk.download('stopwords')

stopwords = nltk.corpus.stopwords.words('spanish')
tokenizer = RegexpTokenizer("[\w’]+", flags=re.UNICODE)

folder = '/home/rr/Desktop/ML/BORME/borme/dias/test/'
# Out:
# [nltk_data] Downloading package stopwords to /home/rr/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Define helper functions

# %%
#Compute the frequency for each term.
def freq(word, tokens):
    return tokens.count(word)
#Count the number of words in a document
def word_count(doc):
    return len(doc)

#Compute the frequency of the term in the document
def tf(word, doc):
    return (freq(word, doc) / float(word_count(doc)))

#Compute the number of documents where a term is found
def num_docs_containing(word, list_of_docs):
    count = 0
    for document in list_of_docs:
        if freq(word, document) > 0:
            count += 1
    return 1 + count

#Compute the inverse document frequency
def idf(word, list_of_docs):
    return math.log(len(list_of_docs) /
            float(num_docs_containing(word, list_of_docs)))


def tf_idf(word, doc, list_of_docs):
    return (tf(word, doc) * idf(word, list_of_docs))

# %% [markdown]
# # Create a vocabulary of tokens from the list of documents and model the Vector Space
#
# The code below tokenizes each document in the corpus and computes the term frequencies.
# Once each of the documents in the corpus has been tokenized, the next step is to compute the document frequency quantity, that is, for each term, how many documents that term appears in.
# This can be represented as a very sparse matrix where the rows are each sentence and the columns each term, giving place to a vector space of zeroes and ones.
# Before going to IDF, it is important to normalize the term-frequencies to avoid bias torwards long documents, or excessively repeated terms.
# The VSM is an algebraic model representing the importance of a term (tf-idf) or even the absence or presence (Bag of Words) of it in a document.

# %%
vocabulary = []
docs = {}
all_tips = []


dirs=os.listdir(folder)
dic={}
print('Processing',len(dirs),'files')
for fname in dirs:
    wordcounts={}
    dic[fname]=wordcounts
    if fname=='.DS_Store':
        continue
    text=open(folder+'/'+ fname,'r')
    for line in text:
        line=line.split('\n')
        line=line[0]

        tokens = tokenizer.tokenize(line)

        bi_tokens = bigrams(tokens)
        tri_tokens = trigrams(tokens)
        tokens = [token.lower() for token in tokens if len(token) > 2]
        tokens = [token for token in tokens if token not in stopwords]

        bi_tokens = [' '.join(token).lower() for token in bi_tokens]
        bi_tokens = [token for token in bi_tokens if token not in stopwords]

        tri_tokens = [' '.join(token).lower() for token in tri_tokens]
        tri_tokens = [token for token in tri_tokens if token not in stopwords]

        final_tokens = []
        final_tokens.extend(tokens)
        final_tokens.extend(bi_tokens)
        final_tokens.extend(tri_tokens)
        docs[line] = {'freq': {}, 'tf': {}, 'idf': {}, 'tf-idf': {}, 'tokens': []}

        for token in final_tokens:
            #The frequency computed for each tip
            docs[line]['freq'][token] = freq(token, final_tokens)
            #The term-frequency (Normalized Frequency)
            docs[line]['tf'][token] = tf(token, final_tokens)
            docs[line]['tokens'] = final_tokens

        vocabulary.append(final_tokens)
print('Vocabulary created,', len(vocabulary),'tokens included and normalized')
# Out:
# Processing 5 files
# Vocabulary created, 1405 tokens included and normalized

# %% [markdown]
# # Compute the TF-IDF
#
# The TF-IDF is the product between the TF and IDF. So a high weight of the tf-idf is reached when you have a high term frequency (tf) in the given document and low document frequency of the term in the whole collection.

# %%
for doc in docs:
    for token in docs[doc]['tf']:
        #The Inverse-Document-Frequency
        docs[doc]['idf'][token] = idf(token, vocabulary)
        #The tf-idf
        docs[doc]['tf-idf'][token] = tf_idf(token, docs[doc]['tokens'], vocabulary)
print('TF-IDF computed')
# Out:
# TF-IDF computed

# %% [markdown]
# # Output the most relevant words

# %%
#Now let's find out the most relevant words by tf-idf.
words = {}
for doc in docs:
    for token in docs[doc]['tf-idf']:
        if token not in words:
            words[token] = docs[doc]['tf-idf'][token]
        else:
            if docs[doc]['tf-idf'][token] > words[token]:
                words[token] = docs[doc]['tf-idf'][token]
print('Displaying results')
for item in sorted(words.items(), key=lambda x: x[1], reverse=True):
    print ("%f <= %s" % (item[1], item[0]))
# Out:
# Displaying results
# 6.554645 <= castellón
# 5.861498 <= badajoz
# 5.638355 <= albacete
# 5.638355 <= alicante
# 5.456033 <= empresarios
# 3.277323 <= pág 7
# 3.277323 <= pág 5
# 3.277323 <= pág 25
# 3.277323 <= pág 4
# 3.277323 <= pág 8
# 3.277323 <= pág 23
# 3.277323 <= pág 1
# 3.277323 <= pág 22
# 3.277323 <= pág 18
# 3.277323 <= pág 15
# 3.277323 <= pág 9
# 3.277323 <= pág 10
# 3.277323 <= pág 12
# 3.277323 <= pág 19
# 3.277323 <= pág 20
# 3.277323 <= pág 2
# 3.277323 <= pág 3
# 3.277323 <= pág 21
# 3.277323 <= pág 11
# 3.277323 <= pág 16
# 3.277323 <= pág 13
# 3.277323 <= pág 17
# 3.277323 <= pág 6
# 3.277323 <= pág 14
# 3.277323 <= pág 24
# 1.994848 <= núm 1
# 1.994848 <= pág
# 1.994848 <= núm
# 1.818678 <= actos inscritos
# 1.818678 <= sección primera
# 1.818678 <= inscritos
# 1.818678 <= actos
# 1.767294 <= sección
# 1.767294 <= primera
# 1.767294 <= ciudad real
# 1.722784 <= ciudad
# 1.648402 <= real
# 1.638661 <= 82 pascampo sl
# 1.638661 <= 51 castrus
# 1.638661 <= 29 arfriotex
# 1.638661 <= 72 isomedia sl
# 1.638661 <= 29 arfriotex sl
# 1.638661 <= pirosellers sl
# 1.638661 <= 59 esamzo sl
# 1.638661 <= distrenba sl
# 1.638661 <= 59 esamzo
# 1.638661 <= isomedia
# 1.638661 <= distrenba
# 1.638661 <= pagnotta
# 1.638661 <= castrus sl
# 1.638661 <= 75 pagnotta
# 1.638661 <= pascampo
# 1.638661 <= 82 pascampo
# 1.638661 <= 75 pagnotta sl
# 1.638661 <= pagnotta sl
# 1.638661 <= dronesalicante
# 1.638661 <= 69 distrenba
# 1.638661 <= pascampo sl
# 1.638661 <= 87 pirosellers sl
# 1.638661 <= arfriotex
# 1.638661 <= castrus
# 1.638661 <= 47 marmedat
# 1.638661 <= 87 pirosellers
# 1.638661 <= dronesalicante sl
# 1.638661 <= pirosellers
# 1.638661 <= isomedia sl
# 1.056752 <= 22 12
# 1.033670 <= 3 22 12
# 1.033670 <= 3 22
# 0.963695 <= 21 12 17
# 0.963695 <= 21 12
# 0.936378 <= trading ubeda sl
# 0.936378 <= rate sl
# 0.936378 <= antobran 1966 sl
# 0.936378 <= lia
# 0.936378 <= plasticos vicent
# 0.936378 <= footwear
# 0.936378 <= telestrong international sl
# 0.936378 <= 31 cafeteria buscavidas
# 0.936378 <= suabal sl
# 0.936378 <= energia maiteca
# 0.936378 <= maiteca
# 0.936378 <= 60 oftalmologia
# 0.936378 <= vistahermosa
# 0.936378 <= rate
# 0.936378 <= oftalmologia vistahermosa
# 0.936378 <= cafeteria buscavidas sl
# 0.936378 <= trading ubeda
# 0.936378 <= lopez sl
# 0.936378 <= vicent
# 0.936378 <= 74 celebraciones
# 0.936378 <= 43 canalizaciones
# 0.936378 <= pardo sl
# 0.936378 <= 1966 sl
# 0.936378 <= 27 proyectados
# 0.936378 <= proyectados ignifugos
# 0.936378 <= 68 antobran 1966
# 0.936378 <= 68 antobran
# 0.936378 <= 53 acabados
# 0.936378 <= yin
# 0.936378 <= 25 titania
# 0.936378 <= canalizaciones
# 0.936378 <= aridos lopez sl
# 0.936378 <= 85 trading ubeda
# 0.936378 <= ubeda sl
# 0.936378 <= audem 2001
# 0.936378 <= optica
# 0.936378 <= marial
# 0.936378 <= 73 energia maiteca
# 0.936378 <= 65 momenti
# 0.936378 <= 63 audem 2001
# 0.936378 <= apartamentos benigracia
# 0.936378 <= construcciones alguelx
# 0.936378 <= alguelx sl
# 0.936378 <= cafeteria
# 0.936378 <= 77 construcciones
# 0.936378 <= llamusi sl
# 0.936378 <= 46 apartamentos
# 0.936378 <= geslim lia
# 0.936378 <= momenti
# 0.936378 <= acabados marial sl
# 0.936378 <= 31 cafeteria
# 0.936378 <= plasticos vicent sl
# 0.936378 <= nadine investment sl
# 0.936378 <= investment
# 0.936378 <= proyectos suabal
# 0.936378 <= nadine
# 0.936378 <= lia sl
# 0.936378 <= acabados marial
# 0.936378 <= celebraciones
# 0.936378 <= vistahermosa sl
# 0.936378 <= 74 celebraciones ilicitanas
# 0.936378 <= 43 canalizaciones pardo
# 0.936378 <= cafeteria buscavidas
# 0.936378 <= 85 trading
# 0.936378 <= titania
# 0.936378 <= momenti footwear sl
# 0.936378 <= 77 construcciones alguelx
# 0.936378 <= footwear sl
# 0.936378 <= admiral rate sl
# 0.936378 <= benigracia sl
# 0.936378 <= proyectados
# 0.936378 <= 46 apartamentos benigracia
# 0.936378 <= 60 oftalmologia vistahermosa
# 0.936378 <= geslim lia sl
# 0.936378 <= audem
# 0.936378 <= 58 telestrong international
# 0.936378 <= momenti footwear
# 0.936378 <= admiral rate
# 0.936378 <= 25 titania publicidad
# 0.936378 <= 86 tutorias illice
# 0.936378 <= antobran 1966
# 0.936378 <= oftalmologia
# 0.936378 <= 86 tutorias
# 0.936378 <= telestrong international
# 0.936378 <= celebraciones ilicitanas
# 0.936378 <= 39 geslim lia
# 0.936378 <= apartamentos
# 0.936378 <= 61 proyectos suabal
# 0.936378 <= canalizaciones pardo sl
# 0.936378 <= 27 proyectados ignifugos
# 0.936378 <= buscavidas sl
# 0.936378 <= 63 audem
# 0.936378 <= aridos
# 0.936378 <= titania publicidad sl
# 0.936378 <= proyectados ignifugos sl
# 0.936378 <= admiral
# 0.936378 <= ignifugos sl
# 0.936378 <= 78 admiral
# 0.936378 <= nadine investment
# 0.936378 <= investment sl
# 0.936378 <= 58 telestrong
# 0.936378 <= international sl
# 0.936378 <= telestrong
# 0.936378 <= 38 aridos lopez
# 0.936378 <= celebraciones ilicitanas sl
# 0.936378 <= apartamentos benigracia sl
# 0.936378 <= 23 nadine investment
# 0.936378 <= buscavidas
# 0.936378 <= international
# 0.936378 <= audem 2001 sl
# 0.936378 <= 23 nadine
# 0.936378 <= 37 plasticos vicent
# 0.936378 <= optica llamusi sl
# 0.936378 <= antobran
# 0.936378 <= oftalmologia vistahermosa sl
# 0.936378 <= ignifugos
# 0.936378 <= geslim
# 0.936378 <= titania publicidad
# 0.936378 <= illice sl
# 0.936378 <= alguelx
# 0.936378 <= 53 acabados marial
# 0.936378 <= 73 energia
# 0.936378 <= 78 admiral rate
# 0.936378 <= tutorias illice
# 0.936378 <= optica llamusi
# 0.936378 <= aridos lopez
# 0.936378 <= illice
# 0.936378 <= ilicitanas sl
# 0.936378 <= publicidad sl
# 0.936378 <= tutorias
# 0.936378 <= ilicitanas
# 0.936378 <= maiteca sl
# 0.936378 <= plasticos
# 0.936378 <= 38 aridos
# 0.936378 <= marial sl
# 0.936378 <= 61 proyectos
# 0.936378 <= 39 geslim
# 0.936378 <= tutorias illice sl
# 0.936378 <= 1966
# 0.936378 <= construcciones alguelx sl
# 0.936378 <= proyectos suabal sl
# 0.936378 <= 37 plasticos
# 0.936378 <= energia maiteca sl
# 0.936378 <= benigracia
# 0.936378 <= vicent sl
# 0.936378 <= 56 optica llamusi
# 0.936378 <= suabal
# 0.936378 <= publicidad
# 0.936378 <= 56 optica
# 0.936378 <= 65 momenti footwear
# 0.936378 <= canalizaciones pardo
# 0.878454 <= trading
# 0.878454 <= llamusi
# 0.878454 <= acabados
# 0.878454 <= 2001
# 0.878454 <= 2001 sl
# 0.837357 <= ubeda
# 0.837357 <= energia
# 0.837357 <= pardo
# 0.819331 <= maxima ceramica sl
# 0.819331 <= puertas alvarez
# 0.819331 <= 308
# 0.819331 <= 412 africa banjat
# 0.819331 <= 310 trans
# 0.819331 <= 389
# 0.819331 <= 395 costa bellver
# 0.819331 <= guzman
# 0.819331 <= 355 chemipol
# 0.819331 <= 426 mesal
# 0.819331 <= 407 bandalay
# 0.819331 <= pelliche investiments
# 0.819331 <= toclimo
# 0.819331 <= 399 vialar autos
# 0.819331 <= 329 hispallor inmobiliaria
# 0.819331 <= gama decor sa
# 0.819331 <= 301
# 0.819331 <= 408
# 0.819331 <= noken design
# 0.819331 <= sinforoso aibar sl
# 0.819331 <= 405
# 0.819331 <= 399 vialar
# 0.819331 <= 389 miura ceramicas
# 0.819331 <= 390
# 0.819331 <= sinforoso aibar
# 0.819331 <= 427 mesal
# 0.819331 <= 327
# 0.819331 <= 324
# 0.819331 <= 319 masia
# 0.819331 <= 401 munatrans
# 0.819331 <= maxima
# 0.819331 <= continuum iberica sl
# 0.819331 <= banjat sl
# 0.819331 <= miura ceramicas
# 0.819331 <= iff benicarlo
# 0.819331 <= lullaby
# 0.819331 <= 417
# 0.819331 <= ceramicas sl
# 0.819331 <= design
# 0.819331 <= pool sa
# 0.819331 <= 49 toclimo
# 0.819331 <= alapar benicasim
# 0.781533 <= samper
# 0.779433 <= construcciones
# 0.768648 <= costa
# 0.768648 <= bandalay music sl
# 0.768648 <= salvia
# 0.768648 <= mesal
# 0.768648 <= mesal instrumentacion
# 0.768648 <= 400
# 0.768648 <= ceramicas
# 0.768648 <= instrumentacion
# 0.768648 <= import
# 0.768648 <= music sl
# 0.768648 <= music
# 0.768648 <= mesal instrumentacion sl
# 0.768648 <= 355
# 0.768648 <= operaciones sl
# 0.768648 <= veluza operaciones sl
# 0.768648 <= lozano
# 0.768648 <= bandalay music
# 0.768648 <= bandalay
# 0.768648 <= 310
# 0.768648 <= veluza
# 0.768648 <= aibar
# 0.768648 <= ceramica sl
# 0.768648 <= instrumentacion sl
# 0.768648 <= veluza operaciones
# 0.768648 <= sinforoso
# 0.738336 <= proyectos
# 0.732687 <= ceramica
# 0.728294 <= 32 18 12
# 0.728294 <= 436 nuskado
# 0.728294 <= batimat sociedad anonima
# 0.728294 <= 418 autoliver sociedad
# 0.728294 <= 307
# 0.728294 <= ciudauto sociedad
# 0.728294 <= 8 20 12
# 0.728294 <= azulev
# 0.728294 <= casino al
# 0.728294 <= nuskado
# 0.728294 <= calzados molt bo
# 0.728294 <= artancar sociedad limitada
# 0.728294 <= 84 banco de
# 0.728294 <= jc toys
# 0.728294 <= 40 calzados
# 0.728294 <= i a 35
# 0.728294 <= 8 20
# 0.728294 <= torralotrans
# 0.728294 <= 418 autoliver
# 0.728294 <= torralotrans sociedad
# 0.728294 <= ciudauto sociedad limitada
# 0.728294 <= estudi
# 0.728294 <= azulev sociedad anonima
# 0.728294 <= 423 atomizadora
# 0.728294 <= a 35
# 0.728294 <= bliterlas sociedad
# 0.728294 <= autoliver
# 0.728294 <= torralotrans sociedad limitada
# 0.728294 <= plarq estudi
# 0.728294 <= jc toys spain
# 0.728294 <= 423
# 0.728294 <= 385 artancar sociedad
# 0.728294 <= artancar
# 0.728294 <= 328 azulev
# 0.728294 <= 415
# 0.728294 <= 479
# 0.728294 <= autoliver sociedad
# 0.728294 <= orilab sociedad
# 0.728294 <= 303 plarq estudi
# 0.728294 <= nuskado sociedad
# 0.728294 <= 84 banco
# 0.728294 <= orilab
# 0.728294 <= 479 ciudauto
# 0.728294 <= batimat
# 0.728294 <= 83 banco
# 0.728294 <= casino
# 0.728294 <= bliterlas sociedad limitada
# 0.728294 <= 303
# 0.728294 <= 34 casino
# 0.728294 <= ciudauto
# 0.728294 <= atomizadora sociedad anonima
# 0.728294 <= toys spain
# 0.728294 <= 459 bliterlas sociedad
# 0.728294 <= orilab sociedad limitada
# 0.728294 <= proradi sociedad limitada
# 0.728294 <= 41 jc toys
# 0.728294 <= 465 torralotrans sociedad
# 0.728294 <= 433 proradi
# 0.728294 <= 41 jc
# 0.728294 <= nuskado sociedad limitada
# 0.728294 <= artancar sociedad
# 0.728294 <= a 32 18
# 0.728294 <= atomizadora sociedad
# 0.728294 <= 34 casino al
# 0.728294 <= 328 azulev sociedad
# 0.728294 <= batimat sociedad
# 0.728294 <= calzados molt
# 0.728294 <= 418
# 0.728294 <= 328
# 0.728294 <= casino al mar
# 0.728294 <= molt bo sl
# 0.728294 <= 35 20
# 0.728294 <= a 8 20
# 0.728294 <= 40 calzados molt
# 0.728294 <= mar sl
# 0.728294 <= toys spain sl
# 0.728294 <= 436
# 0.728294 <= a 35 20
# 0.728294 <= 32 18
# 0.728294 <= 307 batimat
# 0.728294 <= 459 bliterlas
# 0.728294 <= 83 banco de
# 0.728294 <= bo sl
# 0.728294 <= plarq estudi slp
# 0.728294 <= 307 batimat sociedad
# 0.728294 <= molt bo
# 0.728294 <= proradi
# 0.728294 <= toys
# 0.728294 <= bliterlas
# 0.728294 <= 35 20 12
# 0.728294 <= 465 torralotrans
# 0.728294 <= estudi slp
# 0.728294 <= molt
# 0.728294 <= 385
# 0.728294 <= 465
# 0.728294 <= 433 proradi sociedad
# 0.728294 <= 303 plarq
# 0.728294 <= autoliver sociedad limitada
# 0.728294 <= 436 nuskado sociedad
# 0.728294 <= al mar sl
# 0.728294 <= 415 orilab sociedad
# 0.728294 <= atomizadora
# 0.728294 <= al mar
# 0.728294 <= plarq
# 0.728294 <= 479 ciudauto sociedad
# 0.728294 <= azulev sociedad
# 0.728294 <= proradi sociedad
# 0.728294 <= 433
# 0.728294 <= 385 artancar
# 0.728294 <= 423 atomizadora sociedad
# 0.728294 <= 415 orilab
# 0.704794 <= puertas
# 0.704794 <= benicarlo
# 0.704794 <= benicasim
# 0.683242 <= sabadell sa
# 0.683242 <= de sabadell sa
# 0.683242 <= banco de sabadell
# 0.683242 <= calzados
# 0.683242 <= 459
# 0.683242 <= i a 32
# 0.683242 <= banco
# 0.683242 <= banco de
# 0.683242 <= de sabadell
# 0.683242 <= a 32
# 0.682004 <= www boe
# 0.682004 <= boe es
# 0.682004 <= www boe es
# 0.682004 <= boe
# 0.682004 <= www
# 0.682004 <= http
# 0.682004 <= http www
# 0.682004 <= http www boe
# 0.680412 <= lopez
# 0.662735 <= rodriguez
# 0.662735 <= alvarez
# 0.655465 <= 28 ima asesores
# 0.655465 <= asesores
# 0.655465 <= 36 musthave
# 0.655465 <= grupotig
# 0.655465 <= 325 molduras de
# 0.655465 <= jeivsa
# 0.655465 <= tabalet sl
# 0.655465 <= de marmol sl
# 0.655465 <= 374 hierros
# 0.655465 <= distribucion
# 0.655465 <= skinklinnik
# 0.655465 <= hipotecaria sl
# 0.655465 <= destaca led
# 0.655465 <= digo digo
# 0.655465 <= destaca
# 0.655465 <= ima asesores
# 0.655465 <= costa blanca sl
# 0.655465 <= rafasur s
# 0.655465 <= hierros
# 0.655465 <= wood carpinteria
# 0.655465 <= amil lago valencia
# 0.655465 <= 122 destaca
# 0.655465 <= 79 almacenes
# 0.655465 <= 130 grupotig telnet
# 0.655465 <= almacenes hermanos pomares
# 0.655465 <= mantenimiento rafasur s
# 0.655465 <= 384 pastisseria
# 0.655465 <= x one enterprise
# 0.655465 <= telnet s l
# 0.655465 <= 130 grupotig
# 0.655465 <= alehxtor transporte
# 0.655465 <= 48 skinklinnik
# 0.655465 <= pastisseria el tabalet
# 0.655465 <= blanca sl
# 0.655465 <= lago valencia sl
# 0.655465 <= 35 inmobiliaria tecnica
# 0.655465 <= e hijos sl
# 0.655465 <= 70 new
# 0.655465 <= grupotig telnet
# 0.655465 <= hipotecaria
# 0.655465 <= digo sl
# 0.655465 <= rafasur s l
# 0.655465 <= new wood
# 0.655465 <= sunglasses
# 0.655465 <= alehxtor transporte distribucion
# 0.655465 <= one enterprise
# 0.655465 <= l antic colonial
# 0.655465 <= destaca led s
# 0.655465 <= pomares sl
# 0.655465 <= digo digo sl
# 0.655465 <= 325
# 0.655465 <= ima
# 0.655465 <= aromas y sabores
# 0.655465 <= jeivsa e hijos
# 0.655465 <= togados sl
# 0.655465 <= bull invest
# 0.655465 <= bull
# 0.655465 <= 67 alehxtor transporte
# 0.655465 <= 384
# 0.655465 <= transporte distribucion
# 0.655465 <= 131 mantenimiento rafasur
# 0.655465 <= skinklinnik costa blanca
# 0.655465 <= 313
# 0.655465 <= 318 jeivsa
# 0.655465 <= 122 destaca led
# 0.655465 <= 79 almacenes hermanos
# 0.655465 <= asesores togados
# 0.655465 <= ima asesores togados
# 0.655465 <= aromas y
# 0.655465 <= 384 pastisseria el
# 0.655465 <= el tabalet sl
# 0.655465 <= 397 servicios
# 0.655465 <= 24 calzados digo
# 0.655465 <= calzados digo digo
# 0.655465 <= sabores
# 0.655465 <= antic colonial
# 0.655465 <= 318
# 0.655465 <= calzados digo
# 0.655465 <= new wood carpinteria
# 0.655465 <= blanca
# 0.655465 <= 48 skinklinnik costa
# 0.655465 <= 44 ole bull
# 0.655465 <= ole
# 0.655465 <= 67 alehxtor
# 0.655465 <= enterprise
# 0.655465 <= emeterio
# 0.655465 <= carpinteria sl
# 0.655465 <= pastisseria
# 0.655465 <= telnet
# 0.655465 <= hermanos pomares sl
# 0.655465 <= 318 jeivsa e
# 0.655465 <= aromas
# 0.655465 <= lago valencia
# 0.655465 <= colonial sa
# 0.655465 <= 320 x one
# 0.655465 <= pastisseria el
# 0.655465 <= ole bull
# 0.655465 <= y sabores
# 0.655465 <= led s
# 0.655465 <= 371 aromas
# 0.655465 <= 398 servicios
# 0.655465 <= inmobiliaria tecnica
# 0.655465 <= 371 aromas y
# 0.655465 <= 320
# 0.655465 <= x one
# 0.655465 <= 325 molduras
# 0.655465 <= y sabores sa
# 0.655465 <= antic colonial sa
# 0.655465 <= 371
# 0.655465 <= sunglasses spain
# 0.655465 <= 36 musthave sunglasses
# 0.655465 <= 313 l
# 0.655465 <= tabalet
# 0.655465 <= one enterprise sl
# 0.655465 <= musthave sunglasses
# 0.655465 <= carpinteria
# 0.655465 <= new
# 0.655465 <= sabores sa
# 0.655465 <= 131 mantenimiento
# 0.655465 <= 313 l antic
# 0.655465 <= transporte distribucion sl
# 0.655465 <= wood carpinteria sl
# 0.655465 <= 35 inmobiliaria
# 0.655465 <= l antic
# 0.655465 <= 320 x
# 0.655465 <= jeivsa e
# 0.655465 <= 368 alcogi sl
# 0.655465 <= inmobiliaria tecnica hipotecaria
# 0.655465 <= hermanos pomares
# 0.655465 <= costa blanca
# 0.655465 <= antic
# 0.655465 <= 33 amil
# 0.655465 <= 70 new wood
# 0.655465 <= grupotig telnet s
# 0.655465 <= distribucion sl
# 0.655465 <= alcogi
# 0.655465 <= bull invest sl
# 0.655465 <= alcogi sl en
# 0.655465 <= musthave
# 0.655465 <= hierros del
# 0.655465 <= 374 hierros del
# 0.655465 <= colonial
# 0.655465 <= alcogi sl
# 0.655465 <= tecnica hipotecaria sl
# 0.655465 <= hijos sl
# 0.655465 <= invest sl
# 0.655465 <= led s l
# 0.655465 <= skinklinnik costa
# 0.655465 <= rafasur
# 0.655465 <= wood
# 0.655465 <= telnet s
# 0.655465 <= 24 calzados
# 0.655465 <= 44 ole
# 0.655465 <= 28 ima
# 0.655465 <= enterprise sl
# 0.655465 <= one
# 0.655465 <= 368
# 0.655465 <= 398 servicios de
# 0.655465 <= mantenimiento rafasur
# 0.655465 <= el tabalet
# 0.655465 <= 397 servicios de
# 0.655465 <= alehxtor
# 0.655465 <= ole bull invest
# 0.655465 <= togados
# 0.655465 <= led
# 0.655465 <= hierros del mediterraneo
# 0.655465 <= asesores togados sl
# 0.655465 <= 374
# 0.655465 <= almacenes hermanos
# 0.655465 <= musthave sunglasses spain
# 0.655465 <= valencia sl
# 0.655465 <= sunglasses spain sl
# 0.655465 <= 368 alcogi
# 0.655465 <= tecnica hipotecaria
# 0.655465 <= 33 amil lago
# 0.651278 <= sabadell
# 0.651278 <= mar
# 0.646044 <= inmobiliaria
# 0.626484 <= 5 21 12
# 0.626484 <= a 5 21
# 0.626484 <= spain sl
# 0.626484 <= 5 21
# 0.626484 <= a 3 18
# 0.626484 <= 3 18 12
# 0.626484 <= 3 18
# 0.614918 <= levante
# 0.614918 <= amil
# 0.614918 <= invest
# 0.614918 <= levante sa
# 0.614918 <= tecnica
# 0.614918 <= lago
# 0.614918 <= hijos
# 0.614918 <= amil lago
# 0.614918 <= servicios de levante
# 0.614918 <= sl en liquidacion
# 0.614918 <= de levante sa
# 0.614918 <= marmol sl
# 0.614918 <= del mediterraneo
# 0.614918 <= e hijos
# 0.614918 <= de marmol
# 0.614918 <= molduras de marmol
# 0.546220 <= 157884 i
# 0.546220 <= 2009 sociedad
# 0.546220 <= pueyo sociedad
# 0.546220 <= ifjm hosteleros
# 0.546220 <= sevicrip sociedad limitada
# 0.546220 <= elche sa
# 0.546220 <= crealia
# 0.546220 <= 125 banca
# 0.546220 <= sevicrip
# 0.546220 <= sertec sociedad
# 0.546220 <= 366 orpacer
# 0.546220 <= 157889 i
# 0.546220 <= planasat
# 0.546220 <= ceramicas sociedad limitada
# 0.546220 <= 403 galadtrans
# 0.546220 <= bulevar sociedad limitada
# 0.546220 <= a i e
# 0.546220 <= sercas consulting sociedad
# 0.546220 <= xiquets del
# 0.546220 <= qvixote sociedad
# 0.546220 <= minerals
# 0.546220 <= 28668 i a
# 0.546220 <= 464 cda logistics
# 0.546220 <= 4 14
# 0.546220 <= spain sociedad
# 0.546220 <= autobuses urbanos de
# 0.546220 <= 351
# 0.546220 <= 344 ifjm hosteleros
# 0.546220 <= 5033
# 0.546220 <= 23103 i a
# 0.546220 <= talleres sertec sociedad
# 0.546220 <= pascual cortes
# 0.546220 <= ribalta negocios
# 0.538877 <= i a 8
# 0.538877 <= a 8
# 0.535295 <= 12 17
# 0.532863 <= 2000
# 0.532863 <= profesional
# 0.531508 <= castellon
# 0.517472 <= abril
# 0.517472 <= teofilo abril
# 0.517472 <= teofilo
# 0.516835 <= liquidacion
# 0.516835 <= en liquidacion
# 0.512578 <= esther
# 0.512578 <= grupo
# 0.512578 <= talleres
# 0.512578 <= agricola
# 0.512432 <= de belleza
# 0.512432 <= 36074 i
# 0.512432 <= hermacon sociedad limitada
# 0.512432 <= y complementos
# 0.512432 <= mcg
# 0.512432 <= 2 13 12
# 0.512432 <= negocios sociedad
# 0.512432 <= 36074 i a
# 0.512432 <= hermacon sociedad
# 0.512432 <= 5 13
# 0.512432 <= 2018 1 02
# 0.512432 <= pueyo
# 0.512432 <= 2000 sociedad
# 0.512432 <= 473
# 0.512432 <= 2018 1 06
# 0.512432 <= 2 13
# 0.512432 <= belleza
# 0.512432 <= 5 13 12
# 0.512432 <= bolsos y
# 0.512432 <= candido maria
# 0.512432 <= multiservicios sociedad
# 0.512432 <= galindo
# 0.512432 <= a 5 13
# 0.512432 <= 376
# 0.512432 <= multiservicios
# 0.512432 <= 1 06
# 0.512432 <= almacenes hermacon
# 0.512432 <= a 2 13
# 0.512432 <= 1 02
# 0.512432 <= negocios sociedad limitada
# 0.512432 <= almacenes hermacon sociedad
# 0.512432 <= energy
# 0.512432 <= multiservicios sociedad limitada
# 0.512432 <= 36074
# 0.512432 <= hermacon
# 0.512432 <= bolsos
# 0.505057 <= mantenimiento
# 0.504203 <= ediciones
# 0.504203 <= suasoris
# 0.504203 <= macias barrena
# 0.504203 <= hermanos s a
# 0.504203 <= 382 promociones y
# 0.504203 <= y ediciones
# 0.504203 <= metalicas extremeñas s
# 0.504203 <= 132 transportes girol
# 0.504203 <= inversiones varias
# 0.504203 <= varias extremeñas
# 0.504203 <= girol quintero s
# 0.504203 <= culturales sa
# 0.504203 <= 128 alimentacion
# 0.504203 <= alimentacion
# 0.504203 <= alimentacion suarez
# 0.504203 <= de inversiones
# 0.504203 <= del quijote
# 0.504203 <= culturales
# 0.504203 <= cultivos del
# 0.504203 <= alimentacion suarez diaz
# 0.504203 <= 382
# 0.504203 <= 129 macias barrena
# 0.504203 <= metalicas
# 0.504203 <= 134 soluciones
# 0.504203 <= 10 cultivos del
# 0.504203 <= supermercado la
# 0.504203 <= 382 promociones
# 0.504203 <= diaz s l
# 0.504203 <= cultivos del quijote
# 0.504203 <= suasoris assessoria i
# 0.504203 <= soluciones metalicas
# 0.504203 <= quintero s
# 0.504203 <= ossa
# 0.504203 <= almanseña de inversiones
# 0.504203 <= hermanos s
# 0.504203 <= diaz s
# 0.504203 <= 20 almanseña
# 0.504203 <= i gestio sl
# 0.504203 <= suasoris assessoria
# 0.504203 <= 3 supermercado la
# 0.504203 <= quijote sociedad
# 0.504203 <= 20 almanseña de
# 0.504203 <= gestio sl
# 0.504203 <= 129 macias
# 0.504203 <= 128 alimentacion suarez
# 0.504203 <= inversiones varias extremeñas
# 0.504203 <= barrena
# 0.504203 <= macias
# 0.504203 <= de inversiones sociedad
# 0.504203 <= la ossa
# 0.504203 <= 391
# 0.504203 <= la ossa sociedad
# 0.504203 <= assessoria i gestio
# 0.504203 <= supermercado la ossa
# 0.504203 <= assessoria
# 0.504203 <= transportes girol quintero
# 0.504203 <= promociones y ediciones
# 0.504203 <= 135 inversiones varias
# 0.504203 <= cultivos
# 0.504203 <= 135 inversiones
# 0.504203 <= 129
# 0.504203 <= gestio
# 0.504203 <= 391 suasoris
# 0.504203 <= macias barrena hermanos
# 0.504203 <= assessoria i
# 0.504203 <= 134 soluciones metalicas
# 0.504203 <= escrihuela
# 0.504203 <= 10 cultivos
# 0.504203 <= varias
# 0.504203 <= 391 suasoris assessoria
# 0.504203 <= metalicas extremeñas
# 0.504203 <= barrena hermanos s
# 0.504203 <= del quijote sociedad
# 0.504203 <= almanseña de
# 0.504203 <= promociones y
# 0.504203 <= 132 transportes
# 0.504203 <= s a
# 0.504203 <= ossa sociedad
# 0.504203 <= suarez diaz s
# 0.504203 <= quijote sociedad limitada
# 0.504203 <= transportes girol
# 0.504203 <= almanseña
# 0.504203 <= ediciones culturales
# 0.504203 <= quintero s l
# 0.504203 <= varias extremeñas s
# 0.504203 <= ediciones culturales sa
# 0.504203 <= ossa sociedad limitada
# 0.504203 <= soluciones metalicas extremeñas
# 0.504203 <= i gestio
# 0.504203 <= barrena hermanos
# 0.504203 <= 3 supermercado
# 0.504203 <= y ediciones culturales
# 0.496003 <= alonso
# 0.488458 <= 2018 1 13
# 0.488458 <= a 12 22
# 0.488458 <= 4 20 12
# 0.488458 <= transportes
# 0.488458 <= estructuras
# 0.488458 <= candido
# 0.488458 <= ribalta
# 0.488458 <= 12 22
# 0.488458 <= 12 22 12
# 0.488458 <= 4 20
# 0.488458 <= 133
# 0.488458 <= a 4 20
# 0.484990 <= servicios de
# 0.481989 <= 2017
# 0.481989 <= consulting
# 0.473014 <= girol
# 0.473014 <= inversiones sociedad limitada
# 0.473014 <= extremeñas s l
# 0.473014 <= extremeñas s
# 0.473014 <= quijote
# 0.473014 <= extremeñas
# 0.473014 <= quintero
# 0.473014 <= 134
# 0.473014 <= suarez diaz
# 0.473014 <= girol quintero
# 0.469863 <= a 4 18
# 0.469863 <= a 6 21
# 0.469863 <= 6 21 12
# 0.469863 <= pascual
# 0.469863 <= a 2 19
# 0.469863 <= 2 19
# 0.469863 <= 6 21
# 0.469863 <= 4 18 12
# 0.469863 <= 2 19 12
# 0.469863 <= 125
# 0.469863 <= 4 18
# 0.469863 <= complementos
# 0.469850 <= navarro
# 0.469850 <= inversiones
# 0.468189 <= cafe pub
# 0.468189 <= 21 sofia lopez
# 0.468189 <= 94910 i a
# 0.468189 <= 29186 i a
# 0.468189 <= outsourcing services
# 0.468189 <= ultracongelados
# 0.468189 <= 64 j
# 0.468189 <= ab 16428 i
# 0.468189 <= 24727 i
# 0.468189 <= 94910
# 0.468189 <= ejes
# 0.468189 <= ab 16428
# 0.468189 <= cs 24727
# 0.468189 <= ruano
# 0.468189 <= a 104905
# 0.468189 <= ropa
# 0.468189 <= 104905
# 0.468189 <= vicente ballester melchor
# 0.468189 <= campo verde sociedad
# 0.468189 <= 2 moda
# 0.468189 <= ejes sociedad
# 0.468189 <= sofia
# 0.468189 <= market
# 0.468189 <= 11 stratic
# 0.468189 <= 29189
# 0.468189 <= energy market advisors
# 0.468189 <= ejes sociedad limitada
# 0.468189 <= ultracongelados campo verde
# 0.468189 <= 16428
# 0.468189 <= 11389 i a
# 0.468189 <= 94910 i
# 0.468189 <= 29186
# 0.468189 <= yin sociedad
# 0.468189 <= 65309 i a
# 0.468189 <= ab 11389
# 0.468189 <= 24727
# 0.468189 <= ab 8521 i
# 0.468189 <= j j cafe
# 0.468189 <= 16428 i
# 0.468189 <= ballester
# 0.468189 <= outsourcing
# 0.468189 <= a 104905 i
# 0.468189 <= 4 ejes sociedad
# 0.468189 <= 65309
# 0.468189 <= lopez ruano
# 0.468189 <= 364 logistica
# 0.468189 <= sofia lopez
# 0.468189 <= 364 logistica 4
# 0.468189 <= 4 ejes
# 0.468189 <= melchor
# 0.468189 <= 24531
# 0.468189 <= moda yin yin
# 0.468189 <= trabajo villarrobledo
# 0.468189 <= a 94910 i
# 0.468189 <= trabajo villarrobledo sociedad
# 0.468189 <= a 12 14
# 0.468189 <= ultracongelados campo
# 0.468189 <= 12 14 12
# 0.468189 <= ballester melchor sl
# 0.468189 <= j j
# 0.468189 <= advisors
# 0.468189 <= cs 192
# 0.468189 <= cr 29189
# 0.468189 <= market advisors sociedad
# 0.468189 <= 29190
# 0.468189 <= 379
# 0.468189 <= 11389
# 0.468189 <= yin yin
# 0.468189 <= 65309 i
# 0.468189 <= 8521 i
# 0.468189 <= 29189 i
# 0.468189 <= stratic
# 0.468189 <= cr 29190 i
# 0.468189 <= 2 moda yin
# 0.468189 <= yin yin sociedad
# 0.468189 <= services sociedad limitada
# 0.468189 <= stratic outsourcing services
# 0.468189 <= 24531 i a
# 0.468189 <= 64 j j
# 0.468189 <= verde sociedad
# 0.468189 <= cr 24531 i
# 0.468189 <= 104905 i
# 0.468189 <= 16428 i a
# 0.468189 <= ruano sociedad limitada
# 0.468189 <= a 65309 i
# 0.468189 <= ab 11389 i
# 0.468189 <= cr 29190
# 0.468189 <= a 94910
# 0.468189 <= ruano sociedad
# 0.468189 <= 104905 i a
# 0.468189 <= j cafe
# 0.468189 <= advisors sociedad
# 0.468189 <= market advisors
# 0.468189 <= ballester melchor
# 0.468189 <= 379 neumaticos vicente
# 0.468189 <= cafe pub villena
# 0.468189 <= 17 energy
# 0.468189 <= stratic outsourcing
# 0.468189 <= energy market
# 0.468189 <= pub villena
# 0.468189 <= 11 stratic outsourcing
# 0.468189 <= cs 24727 i
# 0.468189 <= moda yin
# 0.468189 <= cafe
# 0.468189 <= ab 8521
# 0.468189 <= 379 neumaticos
# 0.468189 <= villena sl
# 0.468189 <= 12 14
# 0.468189 <= 8 ropa trabajo
# 0.468189 <= vicente ballester
# 0.468189 <= advisors sociedad limitada
# 0.468189 <= 18 ultracongelados
# 0.468189 <= j cafe pub
# 0.468189 <= sofia lopez ruano
# 0.468189 <= yin sociedad limitada
# 0.468189 <= 17 energy market
# 0.468189 <= cr 29189 i
# 0.468189 <= lopez ruano sociedad
# 0.468189 <= 8521
# 0.468189 <= 8 ropa
# 0.468189 <= pub villena sl
# 0.468189 <= services sociedad
# 0.468189 <= 192 i a
# 0.468189 <= 24727 i a
# 0.468189 <= neumaticos vicente ballester
# 0.468189 <= ropa trabajo villarrobledo
# 0.468189 <= 24531 i
# 0.468189 <= cr 24531
# 0.468189 <= services
# 0.468189 <= neumaticos
# 0.468189 <= 29189 i a
# 0.468189 <= verde
# 0.468189 <= 21 sofia
# 0.468189 <= villarrobledo sociedad
# 0.468189 <= 18 ultracongelados campo
# 0.468189 <= outsourcing services sociedad
# 0.468189 <= logistica 4
# 0.468189 <= neumaticos vicente
# 0.468189 <= 29186 i
# 0.468189 <= logistica 4 ejes
# 0.468189 <= villarrobledo sociedad limitada
# 0.468189 <= cr 29186
# 0.468189 <= melchor sl
# 0.468189 <= cr 29186 i
# 0.468189 <= ropa trabajo
# 0.468189 <= a 65309
# 0.468189 <= cs 192 i
# 0.468189 <= verde sociedad limitada
# 0.468189 <= 8521 i a
# 0.468189 <= 29190 i
# 0.468189 <= 192 i
# 0.468189 <= 29190 i a
# 0.468189 <= 11389 i
# 0.468189 <= campo verde
# 0.461189 <= lafuente
# 0.460874 <= s l
# 0.455495 <= rumen
# 0.454669 <= a 4 22
# 0.454669 <= consulting sociedad limitada
# 0.454669 <= 4 22
# 0.454669 <= 4 22 12
# 0.454669 <= consulting sociedad
# 0.454669 <= a 2 15
# 0.454669 <= teruel
# 0.454669 <= negocios
# 0.454669 <= 2 15 12
# 0.454669 <= 2 15
# 0.450884 <= 135
# 0.450884 <= suarez
# 0.450884 <= inversiones sociedad
# 0.450884 <= supermercado
# 0.450884 <= soluciones
# 0.450884 <= 128
# 0.450884 <= 132
# 0.441824 <= 1 03
# 0.441824 <= 2018 1 03
# 0.441824 <= 1 13
# 0.441458 <= servicios
# 0.439227 <= 9 21 12
# 0.439227 <= 9 21
# 0.439227 <= a 5 18
# 0.439227 <= logistica
# 0.439227 <= a 9 21
# 0.439227 <= villena
# 0.439227 <= cs 11418
# 0.439227 <= a 10 22
# 0.439227 <= 11418
# 0.439227 <= moda
# 0.439227 <= pub
# 0.439227 <= 11418 i
# 0.439227 <= villarrobledo
# 0.439227 <= 364
# 0.439227 <= 10 22
# 0.439227 <= giner
# 0.439227 <= 10 22 12
# 0.439227 <= cs 11418 i
# 0.439227 <= 11418 i a
# 0.439227 <= 5 18
# 0.439227 <= 5 18 12
# 0.439106 <= i a 5
# 0.439106 <= a 5
# 0.436976 <= finacon 2007
# 0.436976 <= pachus
# 0.436976 <= inversiones octubre 2014
# 0.436976 <= nourco indus comercial
# 0.436976 <= import export
# 0.436976 <= vinilando soluciones
# 0.436976 <= 420 moda infantil
# 0.436976 <= 2014 sociedad
# 0.436976 <= infantil pachus
# 0.436976 <= guerrero y
# 0.436976 <= eco
# 0.436976 <= caminos
# 0.436976 <= 326
# 0.436976 <= samper samper emeterio
# 0.436976 <= 471 danmar logistica
# 0.436976 <= duran droguerias
# ...
# 0.106573 <= 7 s
# 0.106573 <= f 7
# 0.106573 <= 7 s 8
# 0.106573 <= f 7 s
# 0.106020 <= 90 000 00
# 0.106020 <= capital 90 000
# 0.106020 <= capital 90
# 0.106020 <= capital capital 6
# 0.106020 <= 90 000
# 0.106020 <= capital capital 90
# 0.105720 <= cs 11964
# 0.105720 <= 89 bajo datos
# 0.105720 <= otros conceptos decreto
# 0.105720 <= 446 91
# 0.105720 <= t 867 l
# 0.105720 <= plana calle
# 0.105720 <= 11964
# 0.105720 <= 11964 i a
# 0.105720 <= 24421 i
# 0.105720 <= 713
# 0.105720 <= 30 09 04
# 0.105720 <= calle navarra
# 0.105720 <= 434 f
# 0.105720 <= plana calle navarra
# 0.105720 <= 3 30 09
# 0.105720 <= cs 11964 i
# 0.105720 <= 713 f
# 0.105720 <= 713 f 87
# 0.105720 <= de insolvencia
# 0.105720 <= registrales t 867
# 0.105720 <= 89 bajo
# 0.105720 <= importe de
# 0.105720 <= l 713 f
# 0.105720 <= navarra 89
# 0.105720 <= l 713
# 0.105720 <= 3 30
# 0.105720 <= 867 l 434
# 0.105720 <= h cs 11964
# 0.105720 <= t 949
# 0.105720 <= de insolvencia por
# 0.105720 <= decreto de insolvencia
# 0.105720 <= ab 24421 i
# 0.105720 <= calle navarra 89
# 0.105720 <= 09 04
# 0.105720 <= 434 f 177
# 0.105720 <= ab 24421
# 0.105720 <= la plana calle
# 0.105720 <= por importe
# 0.105720 <= a 3 30
# 0.105720 <= 24421
# 0.105720 <= importe de 9
# 0.105720 <= insolvencia por importe
# 0.105720 <= 949 l 713
# 0.105720 <= 91 euros datos
# 0.105720 <= 11964 i
# 0.105720 <= insolvencia por
# 0.105720 <= 867 l
# 0.105720 <= decreto
# 0.105720 <= l 434
# 0.105720 <= h ab 24421
# 0.105720 <= registrales t 949
# 0.105720 <= conceptos decreto
# 0.105720 <= bajo datos
# 0.105720 <= 30 09
# 0.105720 <= 949
# 0.105720 <= insolvencia
# 0.105720 <= 9 446
# 0.105720 <= 91 euros
# 0.105720 <= navarra
# 0.105720 <= navarra 89 bajo
# 0.105720 <= l 434 f
# 0.105720 <= 949 l
# 0.105720 <= 867
# 0.105720 <= de 9 446
# 0.105720 <= t 949 l
# 0.105720 <= 9 446 91
# 0.105720 <= conceptos decreto de
# 0.105720 <= t 867
# 0.105720 <= 446
# 0.105720 <= por importe de
# 0.105720 <= 446 91 euros
# 0.105720 <= de 9
# 0.105720 <= 24421 i a
# 0.105720 <= decreto de
# 0.105720 <= bajo datos registrales
# 0.105109 <= nombramientos apoderado
# 0.104924 <= inscripción
# 0.104924 <= erratas
# 0.104924 <= fe de
# 0.104924 <= la inscripción
# 0.104924 <= fe de erratas
# 0.104924 <= de erratas
# 0.104694 <= capital 3
# 0.104223 <= f 9 s
# 0.104223 <= 9 s
# 0.104223 <= f 9
# 0.104223 <= 9 s 8
# 0.104042 <= cultivo de la
# 0.104042 <= la vid
# 0.104042 <= 0121 cultivo del
# 0.104042 <= 0121 cultivo
# 0.104042 <= cultivo de
# 0.104042 <= 162
# 0.104042 <= t 596 f
# 0.104042 <= a e
# 0.104042 <= juanes 10
# 0.104042 <= cultivo del
# 0.104042 <= a elche
# 0.104042 <= c pintor juan
# 0.104042 <= de productos químicos
# 0.104042 <= objeto social cultivo
# 0.104042 <= vid
# 0.104042 <= 13663 i a
# 0.104042 <= cultivo del olivo
# 0.104042 <= 596 f
# 0.104042 <= tipo de productos
# 0.104042 <= cr 24330
# 0.104042 <= vid c
# 0.104042 <= n a
# 0.104042 <= del olivo datos
# 0.104042 <= químicos
# 0.104042 <= químicos f la
# 0.104042 <= a 13663
# 0.104042 <= de la vid
# 0.104042 <= c n
# 0.104042 <= 1 a elche
# 0.104042 <= h a 13663
# 0.104042 <= 24330
# 0.104042 <= 596
# 0.104042 <= 10 1
# 0.104042 <= a e 0121
# 0.104042 <= registrales t 1445
# 0.104042 <= f la
# 0.104042 <= 13663 i
# 0.104042 <= ti datos registrales
# 0.104042 <= t 1445
# 0.104042 <= t 596
# 0.104042 <= e 0121
# 0.104042 <= ti datos
# 0.104042 <= a elche datos
# 0.104042 <= e 0121 cultivo
# 0.104042 <= 13663
# 0.104042 <= pintor juan de
# 0.104042 <= 10 1 a
# 0.104042 <= 596 f 7
# 0.104042 <= de juanes
# 0.104042 <= juan de juanes
# 0.104042 <= juanes
# 0.104042 <= juanes 10 1
# 0.104042 <= productos químicos f
# 0.104042 <= de juanes 10
# 0.104042 <= f 162
# 0.104042 <= 162 s
# 0.104042 <= de todo ti
# 0.104042 <= todo ti
# 0.104042 <= del olivo
# 0.104042 <= 0121
# 0.104042 <= c n a
# 0.104042 <= 1445 f
# 0.104042 <= 1445
# 0.104042 <= olivo
# 0.104042 <= social cultivo
# 0.104042 <= f 162 s
# 0.104042 <= vid c n
# 0.104042 <= 365 f 162
# 0.104042 <= a 13663 i
# 0.104042 <= químicos f
# 0.104042 <= f la venta
# 0.104042 <= la vid c
# 0.104042 <= h cr 24330
# 0.104042 <= 1445 f 87
# 0.104042 <= t 1445 f
# 0.104042 <= todo ti datos
# 0.104042 <= social cultivo de
# 0.104042 <= registrales t 596
# 0.104042 <= olivo datos registrales
# 0.104042 <= pintor juan
# 0.104042 <= n a e
# 0.104042 <= productos químicos
# 0.104042 <= 162 s 8
# 0.104042 <= olivo datos
# 0.103489 <= ceses dimisiones adm
# 0.103489 <= dimisiones adm
# 0.102944 <= slp datos registrales
# 0.102944 <= slp datos
# 0.102516 <= elche datos
# 0.102516 <= elche datos registrales
# 0.102486 <= 1 a
# 0.102416 <= erratas error
# 0.102416 <= 361 000 00
# 0.102416 <= euros y
# 0.102416 <= euros y el
# 0.102416 <= aumento siendo la
# 0.102416 <= final siendo el
# 0.102416 <= y el capital
# 0.102416 <= 1 361
# 0.102416 <= erratas error en
# 0.102416 <= la cuantía del
# 0.102416 <= error en
# 0.102416 <= en la cuantía
# 0.102416 <= capital final
# 0.102416 <= capital final siendo
# 0.102416 <= final siendo
# 0.102416 <= siendo la correcta
# 0.102416 <= 1 361 000
# 0.102416 <= cuantía del
# 0.102416 <= el capital
# 0.102416 <= final
# 0.102416 <= correcta 1
# 0.102416 <= inscripción 7ª
# 0.102416 <= inscripción 7ª en
# 0.102416 <= la cuantía
# 0.102416 <= error en la
# 0.102416 <= la correcta
# 0.102416 <= del aumento
# 0.102416 <= de erratas error
# 0.102416 <= 361 000
# 0.102416 <= y el
# 0.102416 <= 7ª en
# 0.102416 <= 7ª en la
# 0.102416 <= cuantía
# 0.102416 <= el capital final
# 0.102416 <= cuantía del aumento
# 0.102416 <= 00 euros y
# 0.102416 <= en la inscripción
# 0.102416 <= error
# 0.102416 <= la correcta 1
# 0.102416 <= la inscripción 7ª
# 0.102416 <= correcta 1 361
# 0.102416 <= aumento siendo
# 0.102416 <= del aumento siendo
# 0.101871 <= de capital
# 0.101437 <= nombramientos adm unico
# 0.101038 <= de capital datos
# 0.099693 <= ceses dimisiones
# 0.099693 <= ceses
# 0.099693 <= dimisiones
# 0.099313 <= acuerdos
# 0.099313 <= l 1130
# 0.099313 <= de deliberar
# 0.099313 <= h cs 33229
# 0.099313 <= forma de deliberar
# 0.099313 <= acuerdos datos
# 0.099313 <= de deliberar y
# 0.099313 <= cambio de la
# 0.099313 <= deliberar
# 0.099313 <= deliberar y
# 0.099313 <= 5 4 12
# 0.099313 <= 33229
# 0.099313 <= cs 33229 i
# 0.099313 <= 33229 i a
# 0.099313 <= f 184 s
# 0.099313 <= 1568 l 1130
# 0.099313 <= 1130 f
# 0.099313 <= y tomar
# 0.099313 <= 33229 i
# 0.099313 <= cs 33229
# 0.099313 <= f 184
# 0.099313 <= 184
# 0.099313 <= 1568
# 0.099313 <= tomar acuerdos
# 0.099313 <= y tomar acuerdos
# 0.099313 <= a 5 4
# 0.099313 <= 1568 l
# 0.099313 <= 184 s
# 0.099313 <= 184 s 8
# 0.099313 <= tomar
# 0.099313 <= t 1568 l
# 0.099313 <= acuerdos datos registrales
# 0.099313 <= t 1568
# 0.099313 <= 5 4
# 0.099313 <= de la forma
# 0.099313 <= registrales t 1568
# 0.099313 <= deliberar y tomar
# 0.099313 <= tomar acuerdos datos
# 0.099313 <= l 1130 f
# 0.099313 <= 1130 f 184
# 0.099180 <= f 87 s
# 0.099180 <= 87 s
# 0.099180 <= 87 s 8
# 0.099180 <= f 87
# 0.098183 <= capital datos
# 0.098183 <= capital datos registrales
# 0.097912 <= reelecciones auditor
# 0.097890 <= domicilio c
# 0.097831 <= correcta de
# 0.097831 <= de 2014 siendo
# 0.097831 <= correcta de la
# 0.097831 <= 2015 datos registrales
# 0.097831 <= de 2015
# 0.097831 <= 2015 datos
# 0.097831 <= misma 14 de
# 0.097831 <= misma
# 0.097831 <= la misma
# 0.097831 <= t 1556 l
# 0.097831 <= fecha correcta de
# 0.097831 <= de 2015 datos
# 0.097831 <= de 2014
# 0.097831 <= mayo de 2014
# 0.097831 <= 2014 siendo
# 0.097831 <= mayo de 2015
# 0.097831 <= misma 14
# 0.097831 <= la misma 14
# 0.097831 <= la fecha correcta
# 0.097831 <= 1556 l 1118
# 0.097831 <= fecha correcta
# 0.097831 <= t 1556
# 0.097831 <= l 1118 f
# 0.097831 <= 1556 l
# 0.097831 <= siendo la fecha
# 0.097831 <= 2014 siendo la
# 0.097831 <= 1556
# 0.097831 <= 1118 f
# 0.097831 <= registrales t 1556
# 0.097831 <= 1118 f 7
# 0.097831 <= l 1118
# 0.097831 <= 1118
# 0.097831 <= de la misma
# 0.096211 <= 17 objeto social
# 0.096211 <= 17 objeto
# 0.096081 <= correcta
# 0.095100 <= sap datos registrales
# 0.095100 <= sap datos
# 0.095100 <= sap
# 0.093529 <= reelecciones auditor dinamic
# 0.093529 <= auditor dinamic auditors
# 0.093529 <= dinamic auditors sap
# 0.093529 <= auditors sap
# 0.093529 <= auditor dinamic
# 0.093529 <= auditors sap datos
# 0.093529 <= dinamic
# 0.093529 <= dinamic auditors
# 0.093115 <= nombramientos adm
# 0.092461 <= 8 h
# 0.092110 <= comienzo
# 0.092110 <= de operaciones
# 0.092110 <= constitución comienzo
# 0.092110 <= comienzo de operaciones
# 0.092110 <= comienzo de
# 0.092110 <= constitución comienzo de
# 0.091571 <= constitución
# 0.089817 <= capital capital
# 0.089817 <= de capital capital
# 0.087423 <= 00 euros resultante
# 0.087303 <= 00 euros datos
# 0.086822 <= nombramientos
# 0.086608 <= solid martin
# 0.086608 <= serrano jesus
# 0.086608 <= serrano jesus otros
# 0.086608 <= angel martin
# 0.086608 <= unico martin consuegra
# 0.086608 <= consuegra lopezserrano jesus
# 0.086608 <= unico martin
# 0.086608 <= jesus nombramientos
# 0.086608 <= lopezserrano
# 0.086608 <= lopezserrano jesus
# 0.086608 <= jesus otros
# 0.086608 <= martin consuegra lopezserrano
# 0.086608 <= miguel angel martin
# 0.086608 <= jesus otros conceptos
# 0.086608 <= lopezserrano jesus nombramientos
# 0.086608 <= lopez serrano miguel
# 0.086608 <= lopez serrano jesus
# 0.086608 <= consuegra lopezserrano
# 0.086608 <= serrano miguel
# 0.086608 <= adm unico martin
# 0.086608 <= angel martin consuegra
# 0.086608 <= jesus nombramientos adm
# 0.086608 <= adm solid martin
# 0.086608 <= serrano miguel angel
# 0.086608 <= solid martin consuegra
# 0.085131 <= s 8 h
# 0.084578 <= resultante
# 0.084578 <= resultante suscrito
# 0.084578 <= euros resultante
# 0.084578 <= suscrito
# 0.084578 <= euros resultante suscrito
# 0.084548 <= s 8
# 0.080832 <= euros datos registrales
# 0.080832 <= euros datos
# 0.078031 <= alfonso nombramientos
# 0.078031 <= llorcacliment beltran
# 0.078031 <= socio único llorca
# 0.078031 <= beltran alfonso datos
# 0.078031 <= unico llorcacliment beltran
# 0.078031 <= llorcacliment beltran alfonso
# 0.078031 <= 86 s 8
# 0.078031 <= f 86
# 0.078031 <= cs 40524
# 0.078031 <= unico llorcacliment
# 0.078031 <= único llorca
# 0.078031 <= adm unico llorcacliment
# 0.078031 <= 40524 i
# 0.078031 <= llorcacliment
# 0.078031 <= climent beltran alfonso
# 0.078031 <= h cs 40524
# 0.078031 <= llorca climent beltran
# 0.078031 <= 40524
# 0.078031 <= alfonso datos
# 0.078031 <= 1306 f 86
# 0.078031 <= único llorca climent
# 0.078031 <= alfonso nombramientos adm
# 0.078031 <= llorca climent
# 0.078031 <= beltran alfonso nombramientos
# 0.078031 <= 86 s
# 0.078031 <= f 86 s
# 0.078031 <= climent beltran
# 0.078031 <= 40524 i a
# 0.078031 <= alfonso datos registrales
# 0.078031 <= cs 40524 i
# 0.075341 <= 6 turismo
# 0.075341 <= barel franck louis
# 0.075341 <= maestrat
# 0.075341 <= alt maestrat 2
# 0.075341 <= y textiles 6
# 0.075341 <= urbanizacion la sella
# 0.075341 <= 7 prestación
# 0.075341 <= s domicilio c
# 0.075341 <= la sella pedreguer
# 0.075341 <= urbanizacion la
# 0.075341 <= 2 urbanizacion
# 0.075341 <= maestrat 2 urbanizacion
# 0.075341 <= sella
# 0.075341 <= 5 industrias
# 0.075341 <= 2 urbanizacion la
# 0.075341 <= s domicilio
# 0.075341 <= franck
# 0.075341 <= textiles 6
# 0.075341 <= 5 industrias manufactureras
# 0.075341 <= c alt
# 0.075341 <= sella pedreguer
# 0.075341 <= y restauración 7
# 0.075341 <= maestrat 2
# 0.075341 <= restauración 7
# 0.075341 <= alt maestrat
# 0.075341 <= solid barel franck
# 0.075341 <= la sella
# 0.075341 <= alt
# 0.075341 <= solid barel
# 0.075341 <= turismo hostelería
# 0.075341 <= de s
# 0.075341 <= barel
# 0.075341 <= textiles 6 turismo
# 0.075341 <= c alt maestrat
# 0.075341 <= turismo hostelería y
# 0.075341 <= pedreguer capital
# 0.075341 <= franck louis
# 0.075341 <= prestación de s
# 0.075341 <= barel franck
# 0.075341 <= pedreguer
# 0.075341 <= adm solid barel
# 0.075341 <= domicilio c alt
# 0.075341 <= louis
# 0.075341 <= restauración 7 prestación
# 0.075341 <= 6 turismo hostelería
# 0.075341 <= de s domicilio
# 0.075341 <= sella pedreguer capital
# 0.075341 <= 7 prestación de
# 0.075341 <= pedreguer capital 3
# 0.072029 <= financiero de terrenos
# 0.072029 <= complementos de los
# 0.072029 <= textiles de piel
# 0.072029 <= c mayor 31
# 0.072029 <= industriales of domicilio
# 0.072029 <= of domicilio
# 0.072029 <= excluido el arrendamiento
# 0.072029 <= otro material la
# 0.072029 <= los mismos
# 0.072029 <= de piel
# 0.072029 <= of domicilio c
# 0.072029 <= textiles de
# 0.072029 <= viviendas naves industriales
# 0.072029 <= textiles complementos
# 0.072029 <= ya sean
# 0.072029 <= de los mismos
# 0.072029 <= 31 33
# 0.072029 <= complementos de
# 0.072029 <= mismos ya
# 0.072029 <= sean textiles
# 0.072029 <= sean textiles de
# 0.072029 <= artículos textiles complementos
# 0.072029 <= textiles complementos de
# 0.072029 <= domicilio c mayor
# 0.072029 <= otro material
# 0.072029 <= naves industriales of
# 0.072029 <= terrenos o
# 0.072029 <= terrenos o edificaciones
# 0.072029 <= c mayor
# 0.072029 <= mismos
# 0.072029 <= piel
# 0.072029 <= la explotación y
# 0.072029 <= naves industriales
# 0.072029 <= de terrenos o
# 0.072029 <= de piel o
# 0.072029 <= industriales of
# 0.072029 <= piel o cualquier
# 0.072029 <= mayor 31 33
# 0.072029 <= ya sean textiles
# 0.072029 <= como viviendas naves
# 0.072029 <= viviendas naves
# 0.072029 <= como viviendas
# 0.072029 <= piel o
# 0.072029 <= mismos ya sean
# 0.072029 <= material la explotación
# 0.072029 <= los mismos ya
# 0.072029 <= o cualquier otro
# 0.072029 <= edificaciones como
# 0.072029 <= naves
# 0.072029 <= el arrendamiento financiero
# 0.072029 <= edificaciones como viviendas
# 0.072029 <= material la
# 0.072029 <= o edificaciones como
# 0.072029 <= o cualquier
# 0.072029 <= cualquier otro material
# 0.072029 <= mayor 31
# 0.072029 <= artículos textiles
# 0.072029 <= o edificaciones
# 0.071246 <= de energía eléctrica
# 0.071246 <= 6820 producción
# 0.071246 <= siguientes alquiler de
# 0.071246 <= de energía
# 0.071246 <= 4619 y siendo
# 0.071246 <= propia cnae
# 0.071246 <= otros tipos cnae
# 0.071246 <= siendo las actividades
# 0.071246 <= energía
# 0.071246 <= producción de energía
# 0.071246 <= eléctrica de
# 0.071246 <= diversos cnae
# 0.071246 <= secundarias las
# 0.071246 <= eléctrica de otros
# 0.071246 <= otros tipos
# 0.071246 <= energía eléctrica
# 0.071246 <= las actividades secundarias
# 0.071246 <= de comercio
# 0.071246 <= tipos cnae
# 0.071246 <= cnae 4619
# 0.071246 <= cuenta propia cnae
# 0.071246 <= eléctrica
# 0.071246 <= tipos cnae 3519
# 0.071246 <= las siguientes alquiler
# 0.071246 <= y siendo las
# 0.071246 <= cnae 3519 datos
# 0.071246 <= siguientes alquiler
# 0.071246 <= 6820
# 0.071246 <= cnae 6820
# 0.071246 <= 3519
# 0.071246 <= 3519 datos
# 0.071246 <= 6820 producción de
# 0.071246 <= de otros
# 0.071246 <= 4619 y
# 0.071246 <= actividades secundarias
# 0.071246 <= de comercio de
# 0.071246 <= de otros tipos
# 0.071246 <= secundarias las siguientes
# 0.071246 <= intermediarios de comercio
# 0.071246 <= actividades secundarias las
# 0.071246 <= secundarias
# 0.071246 <= productos diversos cnae
# 0.071246 <= propia cnae 6820
# 0.071246 <= cnae 3519
# 0.071246 <= producción de
# 0.071246 <= 4619
# 0.071246 <= las siguientes
# 0.071246 <= cnae 6820 producción
# 0.071246 <= siendo las
# 0.071246 <= diversos cnae 4619
# 0.071246 <= primera intermediarios
# 0.071246 <= y siendo
# 0.071246 <= intermediarios de
# 0.071246 <= cnae 4619 y
# 0.071246 <= energía eléctrica de
# 0.071246 <= primera intermediarios de
# 0.071246 <= tipos
# 0.071246 <= producción
# 0.066209 <= h cr 24320
# 0.066209 <= cnae 4122
# 0.066209 <= 24320 i a
# 0.066209 <= cnae 4312preparación
# 0.066209 <= montaje de
# 0.066209 <= y demoliciones cnae
# 0.066209 <= demoliciones cnae 4312preparación
# 0.066209 <= demoliciones cnae
# 0.066209 <= de obras civiles
# 0.066209 <= cub
# 0.066209 <= montaje de estructuras
# 0.066209 <= estructuras y
# 0.066209 <= 4122 la consolidación
# 0.066209 <= t 595 f
# 0.066209 <= y montaje
# 0.066209 <= 4312preparación y
# 0.066209 <= y demoliciones
# 0.066209 <= cr 24320 i
# 0.066209 <= cub datos registrales
# 0.066209 <= 595 f
# 0.066209 <= estructuras y cub
# 0.066209 <= 595
# 0.066209 <= registrales t 595
# 0.066209 <= cnae 4122 la
# 0.066209 <= cub datos
# 0.066209 <= cnae 4312preparación y
# 0.066209 <= de estructuras y
# 0.066209 <= civiles cnae
# 0.066209 <= la consolidación y
# 0.066209 <= 4312preparación
# 0.066209 <= obras civiles cnae
# 0.066209 <= 4122
# 0.066209 <= conservación de obras
# 0.066209 <= 24320 i
# 0.066209 <= 4312preparación y montaje
# 0.066209 <= terrenos y demoliciones
# 0.066209 <= 595 f 186
# 0.066209 <= la consolidación
# 0.066209 <= y cub
# 0.066209 <= civiles cnae 4122
# 0.066209 <= obras civiles
# 0.066209 <= y montaje de
# 0.066209 <= t 595
# 0.066209 <= y cub datos
# 0.066209 <= 4122 la
# 0.066209 <= cr 24320
# 0.066209 <= 24320
# 0.054979 <= datos
# 0.054835 <= datos registrales t
# 0.054199 <= datos registrales
# 0.052127 <= registrales t
# 0.051543 <= registrales
